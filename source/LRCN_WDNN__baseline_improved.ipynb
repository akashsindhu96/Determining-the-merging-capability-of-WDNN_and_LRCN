# %% [markdown]
# ## Connect the gdrive and change working directory to `/content/gdrive/MyDrive/Colab_Notebooks/lrcn/`

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Colab_Notebooks/lrcn/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Colab_Notebooks/lrcn

# %% [markdown]
# ## Load the required packages

# %%
from keras import Sequential, regularizers, Model, Input
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import BatchNormalization, concatenate, add
from tensorflow.keras.optimizers import Adam
from keras.layers import SpatialDropout1D, LSTM, Dense, Dropout, MaxPooling1D, Conv1D, GRU, TimeDistributed, Flatten
import numpy as np
import pandas as pd
import random
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split
import keras.backend as K
# from models import Bayesian_optimizer
from evaluations import plot, ROC_PR
from tensorflow.keras.layers import RepeatVector, Concatenate, Add

# %% [markdown]
# ## Helper functions to load and prepare the data

# %%
def masked_loss_function(y_true, y_pred):
    '''
    Custom loss function
    '''
    mask = K.cast(K.not_equal(y_true, -1), K.floatx())
    return K.binary_crossentropy(y_true * mask, y_pred * mask)


def masked_accuracy(y_true, y_pred):
    '''
    Custom accuracy function.
    '''
    dtype = K.floatx()
    total = K.sum(K.cast(K.not_equal(y_true, -1), dtype))
    correct = K.sum(K.cast(K.equal(y_true, K.round(y_pred)), dtype))
    return correct / total


def prepare_data(features, label, lrcn):
    '''
    This function prepare the data for LRCN and WnD depending on the argment passed.
    '''
    # TODO
    FrameSize = 200

    y = []
    # temp_label = label
    for i in range(0, len(label)):
        # print(i)
        label[i] = label[i].values.tolist()

    for j in range(0, len(label[0])):
        tmp = []
        for i in range(0, len(label)):
            if label[i][j][0] != 0.0 and label[i][j][0] != 1.0:
                tmp.extend([-1])
            else:
                tmp.extend(label[i][j])
        y.append(tmp)


    if lrcn==True:
        X = features.values.tolist()
        for i in range(0, len(X)):
            if len(X[i]) < ((len(X[i]) // FrameSize + 1) * FrameSize):
                for j in range(0, (((len(X[i]) // FrameSize + 1) * FrameSize) - len(X[i]))):
                    X[i].append(0)
            X[i] = np.reshape(X[i], (FrameSize, len(X[i]) // FrameSize))
        X = np.array(X)
        y = np.array(y)
        return X, y, FrameSize

    else:
        features = np.array(features)
        y = np.array(y)
        return features, y, FrameSize


# def prepare_data_wnd(features, label):
#     FrameSize = 200

#     y = []
#     for i in range(0, len(label)):
#         label[i] = label[i].values.tolist()

#     for j in range(0, len(label[0])):
#         tmp = []
#         for i in range(0, len(label)):
#             if label[i][j][0] != 0.0 and label[i][j][0] != 1.0:
#                 tmp.extend([-1])
#             else:
#                 tmp.extend(label[i][j])
#         y.append(tmp)

#     y = np.array(y)
#     features = np.array(features)
#     return features, y, FrameSize



def load_data_gene_dataset(path):
    '''
    This function load the gene burden-based data.
    '''
    dt = pd.read_csv(path + 'gene_data.csv', header=None)
    dt.set_index(dt.columns[0], inplace=True, drop=True)
    return dt



def load_data(lst, path):
    '''
    This function loads the SNP data files 1-38.
    '''

    lst = sorted(np.unique(lst))
    dtypes = dict(zip(list(range(0, 20000)), [np.float32] * 20000))

    if lst[0] == 1:
        dt = pd.read_csv(path + 'SNP_data/' + 'file-' + str(lst[0]) + '.csv', header=None)
        dt.set_index(dt.columns[0], inplace=True, drop=True)
        dt = dt.astype(np.int8)
    else:
        dt = pd.read_csv(path + 'SNP_data/' + 'file-' + str(lst[0]) + '.csv', header=None, dtype=dtypes)
        isolates = pd.read_csv(path + 'iso_list.csv', header=None)[0].values.tolist()
        dt.index = isolates

    for i in lst[1:]:
        tmp = pd.read_csv(path + 'SNP_data/' + 'file-' + str(i) + '.csv', header=None, dtype=dtypes)
        tmp.index = dt.index
        dt = pd.concat([dt, tmp], axis='columns', ignore_index=True)
        print("read {}th file".format(i))

    dt.columns = list(range(0, len(dt.columns)))

    print(dt.shape)
    dt = dt.loc[:, dt.sum() >= 0]
    print("After dropping")
    print(dt.shape)

    return (dt)


def load_label(path):
    '''
    This function load the labels for SNP data.
    '''
    dt = pd.read_csv(path + 'AllLabels' + '.csv')
    dt.set_index(dt.columns[0], inplace=True, drop=True)
    return dt


def process(num_of_files, nrow=0, gene=False, limited=False, gene_dataset=False, shuffle_index=False, random_data=False,
            shuffle_operon=False, shuffle_operon_locally=False, shuffle_operon_group=False, index_file=0):
    
    '''
    Just a helper function.
    '''
    
    if gene:
        df_train = load_data.load_data_gene(list(range(0, num_of_files)), 'Data/')

    # if above condition is not satisfied 
    elif gene_dataset:
        df_train = load_data_gene_dataset('Data/')
    elif shuffle_index:
        df_train = load_data_shuffle_dataset('Data/', index_file)
    elif random_data:
        df_train = load_data_random_dataset('Data/')
    elif shuffle_operon:
        df_train = load_data_operon_dataset('Data/')
    elif shuffle_operon_locally:
        df_train = load_data_operon_locally_dataset('Data/')
    elif shuffle_operon_group:
        df_train = load_data_operon_group_dataset('Data/')
    else:
        df_train = load_data(list(range(1, num_of_files)), 'Data/')

    # df_train = df_train[df_train.columns[df_train.sum() > 5]]

    df_label = load_label('Data/') # read alllabels.csv file 

    if limited:
        df_label = df_label.drop(['ciprofloxacin'], axis=1)
        df_label = df_label.drop(['capreomycin'], axis=1)
        df_label = df_label.drop(['amikacin'], axis=1)
        df_label = df_label.drop(['ethionamide'], axis=1)
        df_label = df_label.drop(['moxifloxacin'], axis=1)


    print('label set: {0}'.format(df_label.shape))

    df_train = df_train.merge(df_label, left_index=True, right_index=True)

    print('train set: {0}'.format(df_train.shape))
    labels = []

    labels_list = []

    dfStreptomycin = df_train[['streptomycin']]
    labels.append(dfStreptomycin)
    labels_list.append(df_train['streptomycin'])

    dfRifampicin = df_train[['rifampicin']]
    labels.append(dfRifampicin)
    labels_list.append(df_train['rifampicin'])

    dfPyrazinamide = df_train[['pyrazinamide']]
    labels.append(dfPyrazinamide)
    labels_list.append(df_train['pyrazinamide'])


    dfOfloxacin = df_train[['ofloxacin']]
    labels.append(dfOfloxacin)
    labels_list.append(df_train['ofloxacin'])


    if not limited:
        dfMoxifloxacin = df_train[['moxifloxacin']]
        labels.append(dfMoxifloxacin)
        labels_list.append(df_train['moxifloxacin'])

    dfKanamycin = df_train[['kanamycin']]
    labels.append(dfKanamycin)
    labels_list.append(df_train['kanamycin'])


    dfIsoniazid = df_train[['isoniazid']]
    labels.append(dfIsoniazid)
    labels_list.append(df_train['isoniazid'])


    if not limited:
        dfEthionamide = df_train[['ethionamide']]
        labels.append(dfEthionamide)
        labels_list.append(df_train['ethionamide'])

    dfEthambutol = df_train[['ethambutol']]
    labels.append(dfEthambutol)
    labels_list.append(df_train['ethambutol'])


    if not limited:
        dfCiprofloxacin = df_train[['ciprofloxacin']]
        labels.append(dfCiprofloxacin)
        labels_list.append(df_train['ciprofloxacin'])

        dfCapreomycin = df_train[['capreomycin']]
        labels.append(dfCapreomycin)
        labels_list.append(df_train['capreomycin'])

        dfAmikacin = df_train[['amikacin']]
        labels.append(dfAmikacin)
        labels_list.append(df_train['amikacin'])

    df_train = df_train.drop(['streptomycin'], axis=1)
    df_train = df_train.drop(['rifampicin'], axis=1)
    df_train = df_train.drop(['pyrazinamide'], axis=1)
    df_train = df_train.drop(['ofloxacin'], axis=1)
    if not limited:
        df_train = df_train.drop(['moxifloxacin'], axis=1)
    df_train = df_train.drop(['kanamycin'], axis=1)
    df_train = df_train.drop(['isoniazid'], axis=1)
    if not limited:
        df_train = df_train.drop(['ethionamide'], axis=1)
    df_train = df_train.drop(['ethambutol'], axis=1)
    if not limited:
        df_train = df_train.drop(['ciprofloxacin'], axis=1)
        df_train = df_train.drop(['capreomycin'], axis=1)
        df_train = df_train.drop(['amikacin'], axis=1)
    # print(dfStreptomycin.head(10))
    if gene:
        df_train = one_hot_gene(df_train)


    # common_elements(labels_list)

    return df_train, labels


def one_hot_gene(df_train):
    # df_train = df_train.iloc[0:50]
    tmp = df_train.values.tolist()
    for i in range(0, len(tmp)):
        if i % 100 == 0:
            print(i)
        for j in range(0, len(tmp[0])):
            one = []
            for k in range(0, len(tmp[i][j])):
                if tmp[i][j][k] == 'A':
                    one.append(True)
                    one.append(False)
                    one.append(False)
                    one.append(False)
                elif tmp[i][j][k] == 'C':
                    one.append(False)
                    one.append(True)
                    one.append(False)
                    one.append(False)
                elif tmp[i][j][k] == 'T':
                    one.append(False)
                    one.append(False)
                    one.append(True)
                    one.append(False)
                elif tmp[i][j][k] == 'G':
                    one.append(False)
                    one.append(False)
                    one.append(False)
                    one.append(True)
                else:
                    print("Error!")
            tmp[i][j] = one
    # print(pd.DataFrame(tmp))
    return pd.DataFrame(tmp)

# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.8 MB/s

# %%
import keras_tuner as kt

# %%
def build_model(X1, X1_train, X1_test, y1_train, y1_test, FrameSize2, X2, X2_train, X2_test, y2_train, y2_test, hp):

    '''
    This is the function for the model Wide and Deep + LRCN. 
    '''

    #channel 1
    input_wnd = Input(shape=(X1_train.shape[1],))

    wnddense_layer_1 = Dense(hp.Int('dense_layer_1', 8, 256, step=8, default=256),activation="relu")(input_wnd)
    wndbatchnorm_layer_1 = BatchNormalization()(wnddense_layer_1)
    wnddropout_1 = Dropout(hp.Float('dropout_1', 0.10, 0.70, step=0.10, default=0.20))(wndbatchnorm_layer_1)
    wnddense_layer_2 = Dense(hp.Int('dense_layer_2', 8, 256, step=8, default=256), activation="relu")(wnddropout_1)
    wndbatchnorm_layer_2 = BatchNormalization()(wnddense_layer_2)
    wnddropout_2 = Dropout(hp.Float('dropout_2', 0.10, 0.70, step=0.10, default=0.20))(wndbatchnorm_layer_2)

    #check the dimensions and shape of WDNN input and output layer
    print("Output shape of input_wnd layer: {}".format(input_wnd.shape))
    print("Output shape of wnddropout_2 layer: {}".format(wnddropout_2.shape))

    #concate 
    wndconcat_layer_1 = concatenate([input_wnd, wnddropout_2], axis=1)
    
    #I can also try add instead of concatenation, some say it works better 
    # wndconcat_layer_1 = add([input_wnd, wnddropout_2])

    # #final layer
    # wndpreds = Dense(12, activation='sigmoid', kernel_regularizer=regularizers.l2(l2_reg))(wndconcat_layer_1)
    # model = Model(inputs=input_wnd, outputs=wndpreds)
    # opt = Adam(lr=0.01)
    # model.compile(optimizer=opt, loss=masked_loss_function, metrics=[masked_accuracy])



    #channel 2
    input_lrcn = Input(shape=(FrameSize2, X2[0].shape[1]))

    lrcnconv1d_layer_1 = Conv1D(filters=hp.Int('filters_1', 8, 32, step=4, default=8), kernel_size=hp.Int('kernel_size_1', 3, 9, step=1, default=3), activation='relu', padding='same')(input_lrcn)
    lrcnmaxpool_layer_1 = MaxPooling1D(pool_size=hp.Int('pool_size_1', 1, 3, step=1, default=3), padding='same')(lrcnconv1d_layer_1)
    lrcnlstm_layer_1 = LSTM(hp.Int('LSTM_layer_1', 8, 256, step=16, default=256), return_sequences=False, recurrent_dropout=0.3)(lrcnmaxpool_layer_1)
    lrcndropout_layer_1 = Dropout(hp.Float('dropout_3', 0.10, 0.70, step=0.10, default=0.10))(lrcnlstm_layer_1)
    lrcndense_layer_1 = Dense(hp.Int('dense_layer_3', 8, 128, step=4, default=64))(lrcndropout_layer_1)
    lrcndropout_layer_2 = Dropout(hp.Float('dropout_4', 0.10, 0.70, step=0.10, default=0.10))(lrcndense_layer_1)



    # correct the shape

    print("Output shape of wnd: {}".format(wndconcat_layer_1.shape))
    # print("Output shape of wnd repeated: {}".format(wndconcat_layer_1_repeated.shape))
    print("Output shape of lrcn: {}".format(lrcndropout_layer_2.shape))

    #concate wnd and lrcn 
    concat_both = concatenate([wndconcat_layer_1, lrcndropout_layer_2], axis=1)

    #interpretation
    dense_layer_prefinal = Dense(hp.Int('dense_layer_4', 8, 128, step=4, default=64), activation='relu')(concat_both)

    #final layer
    preds = Dense(12, activation='sigmoid')(dense_layer_prefinal)


    model = Model(inputs=[input_wnd, input_lrcn], outputs=preds)


    opt = Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling='log'))
    model.compile(optimizer=opt, loss=masked_loss_function, metrics=[masked_accuracy])

    plot_model(model, to_file='Data/plot_/wnd_lrcn_hp_no_of_layers.png', show_shapes=True, show_layer_names=True)

    return model

# %%
def create_plots(model, X1_test, X2_test, y2_test, name):
    """
    This function call the ROC and ROC_Score functions from ROC_PR.py file to
    generate plots for Accuracy, loss, ROC for each and all genes. 
    """

    score = ROC_PR.ROC(model, X1_test, X2_test, y2_test, name, True)
    return score, ROC_PR.ROC_Score(model, [X1_train, X2_train], y2_train, limited=False)

# %% [markdown]
# ## Load WND data

# %%
df_train, labels = process(3, gene_dataset=True)
X1, y1, FrameSize1 = prepare_data(df_train, labels, lrcn=False)
# X1 = to_categorical(X1, dtype=np.int8)
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=1, shuffle=True)
# Out:
# label set: (22376, 12)
# train set: (7845, 3979)

# %% [markdown]
# ## Load LRCN data

# %%
df_train, labels = process(3, gene_dataset=True)
X2, y2, FrameSize2 = prepare_data(df_train, labels, lrcn=True)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=1, shuffle=True)
# Out:
# label set: (22376, 12)
# train set: (7845, 3979)

# %%
# params 
epochs = 50
batch_size = 128
earlyStopping = EarlyStopping(monitor='val_masked_accuracy', mode='max', min_delta=0.1, verbose=1, patience=50)

# %%
from functools import partial

lrs = partial(build_model, X1, X1_train, X1_test, y1_train, y1_test, FrameSize2, X2, X2_train, X2_test, y2_train, y2_test)

# lrs = build_model(kt.HyperParameters(), X1, X1_train, X1_test, y1_train, y1_test, FrameSize2, X2, X2_train, X2_test, y2_train, y2_test)

tuner = kt.BayesianOptimization(
    lrs,
    objective=kt.Objective("val_masked_accuracy", direction="max"),
    max_trials=500,
    seed=42
)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# Output shape of input_wnd layer: (None, 3967)
# Output shape of wnddropout_2 layer: (None, 256)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Output shape of wnd: (None, 4223)
# Output shape of lrcn: (None, 64)
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
#tells us how many hyperparameters we are tuning
#in our case it's 3 =layers,neurons,learning rate
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 13
# dense_layer_1 (Int)
# {'default': 256, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# dropout_1 (Float)
# {'default': 0.2, 'conditions': [], 'min_value': 0.1, 'max_value': 0.7, 'step': 0.1, 'sampling': None}
# dense_layer_2 (Int)
# {'default': 256, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': None}
# dropout_2 (Float)
# {'default': 0.2, 'conditions': [], 'min_value': 0.1, 'max_value': 0.7, 'step': 0.1, 'sampling': None}
# filters_1 (Int)
# {'default': 8, 'conditions': [], 'min_value': 8, 'max_value': 32, 'step': 4, 'sampling': None}
# kernel_size_1 (Int)
# {'default': 3, 'conditions': [], 'min_value': 3, 'max_value': 9, 'step': 1, 'sampling': None}
# pool_size_1 (Int)
# {'default': 3, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': None}
# LSTM_layer_1 (Int)
# {'default': 256, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 16, 'sampling': None}
# dropout_3 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.7, 'step': 0.1, 'sampling': None}
# dense_layer_3 (Int)
# {'default': 64, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 4, 'sampling': None}
# dropout_4 (Float)
# {'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.7, 'step': 0.1, 'sampling': None}
# dense_layer_4 (Int)
# {'default': 64, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 4, 'sampling': None}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
#fitting the tuner
tuner.search([X1_train, X2_train],
             [y1_train, y2_train],
             epochs=epochs,
             batch_size=batch_size,
             steps_per_epoch= len([X2_train][0])//batch_size,
             validation_data=([X1_test, X2_test], y2_test),
             callbacks=[earlyStopping, ModelCheckpoint('Data/lrcn_wnd_checkpoint/lrcn_wnd_optimizer.h5', monitor='val_masked_accuracy', mode='max', save_best_only=True)]
             )

# %%
best_model = tuner.get_best_models(1)[0]
# Out:
# Output shape of input_wnd layer: (None, 3967)
# Output shape of wnddropout_2 layer: (None, 104)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Output shape of wnd: (None, 4071)
# Output shape of lrcn: (None, 8)

# %%
# best_hyperparameters = tuner.get_best_hyperparameters(1)[0]

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='val_masked_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.5
# dense_layer_2: 104
# dropout_2: 0.1
# filters_1: 32
# kernel_size_1: 6
# pool_size_1: 2
# LSTM_layer_1: 8
# dropout_3: 0.30000000000000004
# dense_layer_3: 8
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.00023495992815036312
# Score: 0.8600281476974487
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.5
# dense_layer_2: 64
# dropout_2: 0.1
# filters_1: 24
# kernel_size_1: 7
# pool_size_1: 2
# LSTM_layer_1: 8
# dropout_3: 0.30000000000000004
# dense_layer_3: 24
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.0002840957637286847
# Score: 0.8588727712631226
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.4
# dense_layer_2: 64
# dropout_2: 0.1
# filters_1: 32
# kernel_size_1: 7
# pool_size_1: 2
# LSTM_layer_1: 8
# dropout_3: 0.4
# dense_layer_3: 44
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.0003508937076065728
# Score: 0.8584534525871277
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.1
# dense_layer_2: 8
# dropout_2: 0.4
# filters_1: 8
# kernel_size_1: 9
# pool_size_1: 3
# LSTM_layer_1: 248
# dropout_3: 0.7000000000000001
# dense_layer_3: 12
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.00102534865524399
# Score: 0.8578236699104309
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.7000000000000001
# dense_layer_2: 8
# dropout_2: 0.1
# filters_1: 16
# kernel_size_1: 6
# pool_size_1: 3
# LSTM_layer_1: 8
# dropout_3: 0.1
# dense_layer_3: 128
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.0006892722669296014
# Score: 0.8578011393547058
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.7000000000000001
# dense_layer_2: 8
# dropout_2: 0.1
# filters_1: 24
# kernel_size_1: 9
# pool_size_1: 3
# LSTM_layer_1: 8
# dropout_3: 0.7000000000000001
# dense_layer_3: 56
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.0003900668485316295
# Score: 0.8577944040298462
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.7000000000000001
# dense_layer_2: 8
# dropout_2: 0.1
# filters_1: 20
# kernel_size_1: 7
# pool_size_1: 3
# LSTM_layer_1: 88
# dropout_3: 0.1
# dense_layer_3: 64
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.0003667434128302883
# Score: 0.8576877117156982
# Trial summary
# Hyperparameters:
# dense_layer_1: 176
# dropout_1: 0.2
# dense_layer_2: 96
# dropout_2: 0.1
# filters_1: 32
# kernel_size_1: 7
# pool_size_1: 2
# LSTM_layer_1: 8
# dropout_3: 0.5
# dense_layer_3: 60
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.0006041318566586937
# Score: 0.8574672341346741
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.7000000000000001
# dense_layer_2: 8
# dropout_2: 0.1
# filters_1: 32
# kernel_size_1: 8
# pool_size_1: 3
# LSTM_layer_1: 8
# dropout_3: 0.5
# dense_layer_3: 8
# dropout_4: 0.7000000000000001
# dense_layer_4: 48
# learning_rate: 0.0004121155541862104
# Score: 0.8573808073997498
# Trial summary
# Hyperparameters:
# dense_layer_1: 256
# dropout_1: 0.1
# dense_layer_2: 8
# dropout_2: 0.7000000000000001
# filters_1: 8
# kernel_size_1: 9
# pool_size_1: 3
# LSTM_layer_1: 248
# dropout_3: 0.7000000000000001
# dense_layer_3: 8
# dropout_4: 0.7000000000000001
# dense_layer_4: 128
# learning_rate: 0.000971270330637148
# Score: 0.8573300242424011

# %%
# extract the best model and generate the model plot, model history.
best_model.build()
best_model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f3816d8154bb> in <module>()
#       1 # extract the best model and generate the model plot, model history.
# ----> 2 best_model.build()
#       3 best_model.summary()
#
# TypeError: build() missing 1 required positional argument: 'input_shape'

# %%
# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)

# Build the model with the best hp.
model = lrs(best_hps[0])

# Fit with the entire dataset.
history = model.fit(
                [X1_train, X2_train],
                [y1_train, y2_train],
                epochs=epochs,
                batch_size=batch_size,
                verbose=2,
                steps_per_epoch=len([X2_train][0])//batch_size,
                validation_data=([X1_test, X2_test], y2_test),
                callbacks=[earlyStopping, ModelCheckpoint('Data/lrcn_wnd_checkpoint/lrcn_wnd.h5', monitor='val_masked_accuracy', mode='max', save_best_only=True)]
)
# Out:
# Output shape of input_wnd layer: (None, 3967)
# Output shape of wnddropout_2 layer: (None, 104)
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Output shape of wnd: (None, 4071)
# Output shape of lrcn: (None, 8)
# Epoch 1/50
# 49/49 - 31s - loss: 0.2628 - masked_accuracy: 0.7098 - val_loss: 0.2407 - val_masked_accuracy: 0.7508 - 31s/epoch - 642ms/step
# Epoch 2/50
# 49/49 - 19s - loss: 0.2177 - masked_accuracy: 0.7680 - val_loss: 0.2227 - val_masked_accuracy: 0.7772 - 19s/epoch - 378ms/step
# Epoch 3/50
# 49/49 - 19s - loss: 0.1962 - masked_accuracy: 0.8049 - val_loss: 0.2123 - val_masked_accuracy: 0.7930 - 19s/epoch - 390ms/step
# Epoch 4/50
# 49/49 - 19s - loss: 0.1806 - masked_accuracy: 0.8248 - val_loss: 0.2016 - val_masked_accuracy: 0.8083 - 19s/epoch - 380ms/step
# Epoch 5/50
# 49/49 - 19s - loss: 0.1655 - masked_accuracy: 0.8369 - val_loss: 0.1968 - val_masked_accuracy: 0.8150 - 19s/epoch - 396ms/step
# Epoch 6/50
# 49/49 - 18s - loss: 0.1536 - masked_accuracy: 0.8554 - val_loss: 0.1939 - val_masked_accuracy: 0.8136 - 18s/epoch - 372ms/step
# Epoch 7/50
# 49/49 - 20s - loss: 0.1458 - masked_accuracy: 0.8590 - val_loss: 0.1883 - val_masked_accuracy: 0.8279 - 20s/epoch - 401ms/step
# Epoch 8/50
# 49/49 - 19s - loss: 0.1377 - masked_accuracy: 0.8694 - val_loss: 0.1874 - val_masked_accuracy: 0.8318 - 19s/epoch - 383ms/step
# Epoch 9/50
# 49/49 - 18s - loss: 0.1367 - masked_accuracy: 0.8699 - val_loss: 0.1850 - val_masked_accuracy: 0.8290 - 18s/epoch - 373ms/step
# Epoch 10/50
# 49/49 - 19s - loss: 0.1213 - masked_accuracy: 0.8899 - val_loss: 0.1800 - val_masked_accuracy: 0.8345 - 19s/epoch - 382ms/step
# Epoch 11/50
# 49/49 - 18s - loss: 0.1172 - masked_accuracy: 0.8895 - val_loss: 0.1797 - val_masked_accuracy: 0.8356 - 18s/epoch - 375ms/step
# Epoch 12/50
# 49/49 - 18s - loss: 0.1125 - masked_accuracy: 0.8986 - val_loss: 0.1763 - val_masked_accuracy: 0.8367 - 18s/epoch - 376ms/step
# Epoch 13/50
# 49/49 - 18s - loss: 0.1172 - masked_accuracy: 0.8926 - val_loss: 0.1854 - val_masked_accuracy: 0.8359 - 18s/epoch - 369ms/step
# Epoch 14/50
# 49/49 - 18s - loss: 0.1070 - masked_accuracy: 0.8977 - val_loss: 0.1781 - val_masked_accuracy: 0.8396 - 18s/epoch - 375ms/step
# Epoch 15/50
# 49/49 - 18s - loss: 0.1026 - masked_accuracy: 0.9079 - val_loss: 0.1832 - val_masked_accuracy: 0.8430 - 18s/epoch - 376ms/step
# Epoch 16/50
# 49/49 - 18s - loss: 0.1018 - masked_accuracy: 0.9141 - val_loss: 0.1787 - val_masked_accuracy: 0.8418 - 18s/epoch - 367ms/step
# Epoch 17/50
# 49/49 - 18s - loss: 0.0916 - masked_accuracy: 0.9189 - val_loss: 0.1792 - val_masked_accuracy: 0.8425 - 18s/epoch - 366ms/step
# Epoch 18/50
# 49/49 - 19s - loss: 0.0917 - masked_accuracy: 0.9229 - val_loss: 0.1771 - val_masked_accuracy: 0.8499 - 19s/epoch - 380ms/step
# Epoch 19/50
# 49/49 - 19s - loss: 0.0877 - masked_accuracy: 0.9256 - val_loss: 0.1753 - val_masked_accuracy: 0.8511 - 19s/epoch - 379ms/step
# Epoch 20/50
# 49/49 - 18s - loss: 0.0920 - masked_accuracy: 0.9189 - val_loss: 0.1767 - val_masked_accuracy: 0.8473 - 18s/epoch - 370ms/step
# Epoch 21/50
# 49/49 - 18s - loss: 0.0842 - masked_accuracy: 0.9320 - val_loss: 0.1770 - val_masked_accuracy: 0.8523 - 18s/epoch - 377ms/step
# Epoch 22/50
# 49/49 - 18s - loss: 0.0802 - masked_accuracy: 0.9344 - val_loss: 0.1796 - val_masked_accuracy: 0.8494 - 18s/epoch - 367ms/step
# Epoch 23/50
# 49/49 - 18s - loss: 0.0802 - masked_accuracy: 0.9322 - val_loss: 0.1791 - val_masked_accuracy: 0.8512 - 18s/epoch - 369ms/step
# Epoch 24/50
# 49/49 - 18s - loss: 0.0776 - masked_accuracy: 0.9350 - val_loss: 0.1820 - val_masked_accuracy: 0.8505 - 18s/epoch - 372ms/step
# Epoch 25/50
# 49/49 - 18s - loss: 0.0750 - masked_accuracy: 0.9382 - val_loss: 0.1902 - val_masked_accuracy: 0.8493 - 18s/epoch - 367ms/step
# Epoch 26/50
# 49/49 - 18s - loss: 0.0830 - masked_accuracy: 0.9243 - val_loss: 0.1901 - val_masked_accuracy: 0.8411 - 18s/epoch - 367ms/step
# Epoch 27/50
# 49/49 - 18s - loss: 0.0760 - masked_accuracy: 0.9369 - val_loss: 0.1859 - val_masked_accuracy: 0.8520 - 18s/epoch - 371ms/step
# Epoch 28/50
# 49/49 - 18s - loss: 0.0748 - masked_accuracy: 0.9354 - val_loss: 0.1900 - val_masked_accuracy: 0.8467 - 18s/epoch - 368ms/step
# Epoch 29/50
# 49/49 - 18s - loss: 0.0714 - masked_accuracy: 0.9423 - val_loss: 0.1894 - val_masked_accuracy: 0.8501 - 18s/epoch - 369ms/step
# Epoch 30/50
# 49/49 - 18s - loss: 0.0673 - masked_accuracy: 0.9466 - val_loss: 0.1844 - val_masked_accuracy: 0.8514 - 18s/epoch - 369ms/step
# Epoch 31/50
# 49/49 - 18s - loss: 0.0690 - masked_accuracy: 0.9365 - val_loss: 0.1932 - val_masked_accuracy: 0.8444 - 18s/epoch - 369ms/step
# Epoch 32/50
# 49/49 - 18s - loss: 0.0750 - masked_accuracy: 0.9361 - val_loss: 0.1893 - val_masked_accuracy: 0.8441 - 18s/epoch - 370ms/step
# Epoch 33/50
# 49/49 - 19s - loss: 0.0676 - masked_accuracy: 0.9465 - val_loss: 0.1936 - val_masked_accuracy: 0.8525 - 19s/epoch - 382ms/step
# Epoch 34/50
# 49/49 - 18s - loss: 0.0636 - masked_accuracy: 0.9506 - val_loss: 0.1988 - val_masked_accuracy: 0.8501 - 18s/epoch - 369ms/step
# Epoch 35/50
# 49/49 - 18s - loss: 0.0663 - masked_accuracy: 0.9424 - val_loss: 0.2012 - val_masked_accuracy: 0.8373 - 18s/epoch - 367ms/step
# Epoch 36/50
# 49/49 - 18s - loss: 0.0628 - masked_accuracy: 0.9503 - val_loss: 0.1924 - val_masked_accuracy: 0.8502 - 18s/epoch - 367ms/step
# Epoch 37/50
# 49/49 - 18s - loss: 0.0588 - masked_accuracy: 0.9544 - val_loss: 0.1937 - val_masked_accuracy: 0.8537 - 18s/epoch - 377ms/step
# Epoch 38/50
# 49/49 - 18s - loss: 0.0624 - masked_accuracy: 0.9496 - val_loss: 0.2003 - val_masked_accuracy: 0.8489 - 18s/epoch - 367ms/step
# Epoch 39/50
# 49/49 - 18s - loss: 0.0575 - masked_accuracy: 0.9520 - val_loss: 0.2073 - val_masked_accuracy: 0.8392 - 18s/epoch - 368ms/step
# Epoch 40/50
# 49/49 - 18s - loss: 0.0609 - masked_accuracy: 0.9522 - val_loss: 0.1979 - val_masked_accuracy: 0.8518 - 18s/epoch - 370ms/step
# Epoch 41/50
# 49/49 - 18s - loss: 0.0598 - masked_accuracy: 0.9526 - val_loss: 0.1980 - val_masked_accuracy: 0.8490 - 18s/epoch - 370ms/step
# Epoch 42/50
# 49/49 - 18s - loss: 0.0555 - masked_accuracy: 0.9566 - val_loss: 0.2055 - val_masked_accuracy: 0.8526 - 18s/epoch - 365ms/step
# Epoch 43/50
# 49/49 - 18s - loss: 0.0535 - masked_accuracy: 0.9563 - val_loss: 0.2048 - val_masked_accuracy: 0.8515 - 18s/epoch - 367ms/step
# Epoch 44/50
# 49/49 - 18s - loss: 0.0556 - masked_accuracy: 0.9565 - val_loss: 0.2015 - val_masked_accuracy: 0.8520 - 18s/epoch - 365ms/step
# Epoch 45/50
# 49/49 - 18s - loss: 0.0542 - masked_accuracy: 0.9586 - val_loss: 0.2121 - val_masked_accuracy: 0.8495 - 18s/epoch - 366ms/step
# Epoch 46/50
# 49/49 - 18s - loss: 0.0506 - masked_accuracy: 0.9636 - val_loss: 0.2062 - val_masked_accuracy: 0.8522 - 18s/epoch - 372ms/step
# Epoch 47/50
# 49/49 - 19s - loss: 0.0507 - masked_accuracy: 0.9603 - val_loss: 0.2025 - val_masked_accuracy: 0.8563 - 19s/epoch - 382ms/step
# Epoch 48/50
# 49/49 - 18s - loss: 0.0482 - masked_accuracy: 0.9644 - val_loss: 0.2043 - val_masked_accuracy: 0.8519 - 18s/epoch - 371ms/step
# Epoch 49/50
# 49/49 - 18s - loss: 0.0471 - masked_accuracy: 0.9652 - val_loss: 0.2110 - val_masked_accuracy: 0.8485 - 18s/epoch - 368ms/step
# Epoch 50/50
# 49/49 - 18s - loss: 0.0512 - masked_accuracy: 0.9623 - val_loss: 0.1998 - val_masked_accuracy: 0.8543 - 18s/epoch - 370ms/step

# %%
best_hps[0]

# %%
# after getting the best model, generate the plots.
for i in range(0,2):
    plot.plot(history, ("LRCN" + "gene_10_" + str(i)))
    create_plots(model, X1_test, X2_test, y2_test, name = ("LRCN" + "gene_10_" + str(i)))

# %%
plot_model(model, to_file='Data/plot_/wnd_lrcn_hp_no_of_layers.png', show_shapes=True, show_layer_names=True)

# %%
# Out:
# label set: (22376, 12)
# train set: (7845, 3979)
# Output shape of input_wnd layer: (None, 3967)
# Output shape of wnddropout_2 layer: (None, 256)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Output shape of wnd: (None, 4223)
# Output shape of lrcn: (None, 64)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 56/56 - 23s - loss: 0.5243 - masked_accuracy: 0.6466 - val_loss: 0.3152 - val_masked_accuracy: 0.6902 - 23s/epoch - 405ms/step
# Epoch 2/50
# 56/56 - 10s - loss: 0.2683 - masked_accuracy: 0.7314 - val_loss: 0.2711 - val_masked_accuracy: 0.7374 - 10s/epoch - 180ms/step
# Epoch 3/50
# 56/56 - 10s - loss: 0.2467 - masked_accuracy: 0.7668 - val_loss: 0.2546 - val_masked_accuracy: 0.7621 - 10s/epoch - 182ms/step
# Epoch 4/50
# 56/56 - 10s - loss: 0.2247 - masked_accuracy: 0.7953 - val_loss: 0.2404 - val_masked_accuracy: 0.8017 - 10s/epoch - 180ms/step
# Epoch 5/50
# 56/56 - 10s - loss: 0.2007 - masked_accuracy: 0.8184 - val_loss: 0.2313 - val_masked_accuracy: 0.8101 - 10s/epoch - 181ms/step
# Epoch 6/50
# 56/56 - 10s - loss: 0.1906 - masked_accuracy: 0.8246 - val_loss: 0.2219 - val_masked_accuracy: 0.8104 - 10s/epoch - 180ms/step
# Epoch 7/50
# 56/56 - 10s - loss: 0.1838 - masked_accuracy: 0.8345 - val_loss: 0.2334 - val_masked_accuracy: 0.8086 - 10s/epoch - 181ms/step
# Epoch 8/50
# 56/56 - 10s - loss: 0.1745 - masked_accuracy: 0.8375 - val_loss: 0.2306 - val_masked_accuracy: 0.7859 - 10s/epoch - 178ms/step
# Epoch 9/50
# 56/56 - 11s - loss: 0.1766 - masked_accuracy: 0.8403 - val_loss: 0.2120 - val_masked_accuracy: 0.8116 - 11s/epoch - 194ms/step
# Epoch 10/50
# 56/56 - 10s - loss: 0.1622 - masked_accuracy: 0.8438 - val_loss: 0.2051 - val_masked_accuracy: 0.8282 - 10s/epoch - 180ms/step
# Epoch 11/50
# 56/56 - 10s - loss: 0.1518 - masked_accuracy: 0.8563 - val_loss: 0.2028 - val_masked_accuracy: 0.8133 - 10s/epoch - 178ms/step
# Epoch 12/50
# 56/56 - 11s - loss: 0.1486 - masked_accuracy: 0.8597 - val_loss: 0.1936 - val_masked_accuracy: 0.8314 - 11s/epoch - 193ms/step
# Epoch 13/50
# 56/56 - 10s - loss: 0.1401 - masked_accuracy: 0.8665 - val_loss: 0.2055 - val_masked_accuracy: 0.8256 - 10s/epoch - 180ms/step
# Epoch 14/50
# 56/56 - 11s - loss: 0.1388 - masked_accuracy: 0.8644 - val_loss: 0.1956 - val_masked_accuracy: 0.8381 - 11s/epoch - 195ms/step
# Epoch 15/50
# 56/56 - 10s - loss: 0.1367 - masked_accuracy: 0.8690 - val_loss: 0.1975 - val_masked_accuracy: 0.8143 - 10s/epoch - 179ms/step
# Epoch 16/50
# 56/56 - 10s - loss: 0.1318 - masked_accuracy: 0.8716 - val_loss: 0.2013 - val_masked_accuracy: 0.8353 - 10s/epoch - 180ms/step
# Epoch 17/50
# 56/56 - 11s - loss: 0.1278 - masked_accuracy: 0.8777 - val_loss: 0.2154 - val_masked_accuracy: 0.8381 - 11s/epoch - 195ms/step
# Epoch 18/50
# 56/56 - 10s - loss: 0.1237 - masked_accuracy: 0.8823 - val_loss: 0.2094 - val_masked_accuracy: 0.8325 - 10s/epoch - 179ms/step
# Epoch 19/50
# 56/56 - 10s - loss: 0.1256 - masked_accuracy: 0.8787 - val_loss: 0.2232 - val_masked_accuracy: 0.8330 - 10s/epoch - 177ms/step
# Epoch 20/50
# 56/56 - 10s - loss: 0.1491 - masked_accuracy: 0.8598 - val_loss: 0.2295 - val_masked_accuracy: 0.8318 - 10s/epoch - 177ms/step
# Epoch 21/50
# 56/56 - 10s - loss: 0.1440 - masked_accuracy: 0.8712 - val_loss: 0.2079 - val_masked_accuracy: 0.8268 - 10s/epoch - 178ms/step
# Epoch 22/50
# 56/56 - 10s - loss: 0.1229 - masked_accuracy: 0.8839 - val_loss: 0.2047 - val_masked_accuracy: 0.8339 - 10s/epoch - 178ms/step
# Epoch 23/50
# 56/56 - 10s - loss: 0.1294 - masked_accuracy: 0.8818 - val_loss: 0.2168 - val_masked_accuracy: 0.8220 - 10s/epoch - 177ms/step
# Epoch 24/50
# 56/56 - 10s - loss: 0.1276 - masked_accuracy: 0.8815 - val_loss: 0.2164 - val_masked_accuracy: 0.8231 - 10s/epoch - 178ms/step
# Epoch 25/50
# 56/56 - 10s - loss: 0.1189 - masked_accuracy: 0.8875 - val_loss: 0.2139 - val_masked_accuracy: 0.8364 - 10s/epoch - 178ms/step
# Epoch 26/50
# 56/56 - 10s - loss: 0.1159 - masked_accuracy: 0.8883 - val_loss: 0.2247 - val_masked_accuracy: 0.8365 - 10s/epoch - 179ms/step
# Epoch 27/50
# 56/56 - 10s - loss: 0.1143 - masked_accuracy: 0.8931 - val_loss: 0.2220 - val_masked_accuracy: 0.8275 - 10s/epoch - 178ms/step
# Epoch 28/50
# 56/56 - 10s - loss: 0.1142 - masked_accuracy: 0.8926 - val_loss: 0.2290 - val_masked_accuracy: 0.8235 - 10s/epoch - 179ms/step
# Epoch 29/50
# 56/56 - 10s - loss: 0.1141 - masked_accuracy: 0.8941 - val_loss: 0.2445 - val_masked_accuracy: 0.8360 - 10s/epoch - 181ms/step
# Epoch 30/50
# 56/56 - 10s - loss: 0.1129 - masked_accuracy: 0.8949 - val_loss: 0.2359 - val_masked_accuracy: 0.8307 - 10s/epoch - 179ms/step
# Epoch 31/50
# 56/56 - 10s - loss: 0.1137 - masked_accuracy: 0.8941 - val_loss: 0.2318 - val_masked_accuracy: 0.8343 - 10s/epoch - 179ms/step
# Epoch 32/50
# 56/56 - 11s - loss: 0.1103 - masked_accuracy: 0.9008 - val_loss: 0.2448 - val_masked_accuracy: 0.8388 - 11s/epoch - 193ms/step
# Epoch 33/50
# 56/56 - 10s - loss: 0.1101 - masked_accuracy: 0.8981 - val_loss: 0.2494 - val_masked_accuracy: 0.8381 - 10s/epoch - 178ms/step
# Epoch 34/50
# 56/56 - 10s - loss: 0.1094 - masked_accuracy: 0.8992 - val_loss: 0.2262 - val_masked_accuracy: 0.8316 - 10s/epoch - 183ms/step
# Epoch 35/50
# 56/56 - 10s - loss: 0.1115 - masked_accuracy: 0.8960 - val_loss: 0.2276 - val_masked_accuracy: 0.8235 - 10s/epoch - 180ms/step
# Epoch 36/50
# 56/56 - 10s - loss: 0.1142 - masked_accuracy: 0.8971 - val_loss: 0.2400 - val_masked_accuracy: 0.8115 - 10s/epoch - 179ms/step
# Epoch 37/50
# 56/56 - 10s - loss: 0.1182 - masked_accuracy: 0.8986 - val_loss: 0.2451 - val_masked_accuracy: 0.8309 - 10s/epoch - 178ms/step
# Epoch 38/50
# 56/56 - 11s - loss: 0.1094 - masked_accuracy: 0.9012 - val_loss: 0.2421 - val_masked_accuracy: 0.8443 - 11s/epoch - 193ms/step
# Epoch 39/50
# 56/56 - 10s - loss: 0.1033 - masked_accuracy: 0.9047 - val_loss: 0.2432 - val_masked_accuracy: 0.8420 - 10s/epoch - 181ms/step
# Epoch 40/50
# 56/56 - 10s - loss: 0.1076 - masked_accuracy: 0.9043 - val_loss: 0.2707 - val_masked_accuracy: 0.8313 - 10s/epoch - 179ms/step
# Epoch 41/50
# 56/56 - 10s - loss: 0.1317 - masked_accuracy: 0.8814 - val_loss: 0.2592 - val_masked_accuracy: 0.8324 - 10s/epoch - 180ms/step
# Epoch 42/50
# 56/56 - 10s - loss: 0.1172 - masked_accuracy: 0.8928 - val_loss: 0.2444 - val_masked_accuracy: 0.8328 - 10s/epoch - 179ms/step
# Epoch 43/50
# 56/56 - 10s - loss: 0.1084 - masked_accuracy: 0.9015 - val_loss: 0.2445 - val_masked_accuracy: 0.8357 - 10s/epoch - 177ms/step
# Epoch 44/50
# 56/56 - 10s - loss: 0.1066 - masked_accuracy: 0.9033 - val_loss: 0.2632 - val_masked_accuracy: 0.8343 - 10s/epoch - 178ms/step
# Epoch 45/50
# 56/56 - 10s - loss: 0.1046 - masked_accuracy: 0.9038 - val_loss: 0.2377 - val_masked_accuracy: 0.8318 - 10s/epoch - 179ms/step
# Epoch 46/50
# 56/56 - 10s - loss: 0.1091 - masked_accuracy: 0.9028 - val_loss: 0.2522 - val_masked_accuracy: 0.8351 - 10s/epoch - 178ms/step
# Epoch 47/50
# 56/56 - 10s - loss: 0.1086 - masked_accuracy: 0.9028 - val_loss: 0.2569 - val_masked_accuracy: 0.8203 - 10s/epoch - 178ms/step
# Epoch 48/50
# 56/56 - 10s - loss: 0.1120 - masked_accuracy: 0.8990 - val_loss: 0.2506 - val_masked_accuracy: 0.8155 - 10s/epoch - 177ms/step
# Epoch 49/50
# 56/56 - 10s - loss: 0.1079 - masked_accuracy: 0.9053 - val_loss: 0.2431 - val_masked_accuracy: 0.8325 - 10s/epoch - 178ms/step
# Epoch 50/50
# 56/56 - 10s - loss: 0.1000 - masked_accuracy: 0.9115 - val_loss: 0.2440 - val_masked_accuracy: 0.8345 - 10s/epoch - 182ms/step
# Output shape of input_wnd layer: (None, 3967)
# Output shape of wnddropout_2 layer: (None, 256)
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Output shape of wnd: (None, 4223)
# Output shape of lrcn: (None, 64)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 56/56 - 14s - loss: 0.4260 - masked_accuracy: 0.7148 - val_loss: 0.2781 - val_masked_accuracy: 0.7580 - 14s/epoch - 244ms/step
# Epoch 2/50
# 56/56 - 10s - loss: 0.2487 - masked_accuracy: 0.7586 - val_loss: 0.2536 - val_masked_accuracy: 0.7584 - 10s/epoch - 182ms/step
# Epoch 3/50
# 56/56 - 10s - loss: 0.2259 - masked_accuracy: 0.7745 - val_loss: 0.2386 - val_masked_accuracy: 0.7692 - 10s/epoch - 182ms/step
# Epoch 4/50
# 56/56 - 10s - loss: 0.2221 - masked_accuracy: 0.7961 - val_loss: 0.2922 - val_masked_accuracy: 0.7706 - 10s/epoch - 184ms/step
# Epoch 5/50
# 56/56 - 11s - loss: 0.2034 - masked_accuracy: 0.8113 - val_loss: 0.2602 - val_masked_accuracy: 0.7870 - 11s/epoch - 188ms/step
# Epoch 6/50
# 56/56 - 11s - loss: 0.1998 - masked_accuracy: 0.8155 - val_loss: 0.2549 - val_masked_accuracy: 0.7902 - 11s/epoch - 198ms/step
# Epoch 7/50
# 56/56 - 10s - loss: 0.1897 - masked_accuracy: 0.8252 - val_loss: 0.2168 - val_masked_accuracy: 0.8139 - 10s/epoch - 184ms/step
# Epoch 8/50
# 56/56 - 10s - loss: 0.1757 - masked_accuracy: 0.8345 - val_loss: 0.2236 - val_masked_accuracy: 0.7882 - 10s/epoch - 184ms/step
# Epoch 9/50
# 56/56 - 10s - loss: 0.1722 - masked_accuracy: 0.8369 - val_loss: 0.2172 - val_masked_accuracy: 0.8085 - 10s/epoch - 181ms/step
# Epoch 10/50
# 56/56 - 11s - loss: 0.1696 - masked_accuracy: 0.8396 - val_loss: 0.2133 - val_masked_accuracy: 0.8180 - 11s/epoch - 196ms/step
# Epoch 11/50
# 56/56 - 10s - loss: 0.1668 - masked_accuracy: 0.8404 - val_loss: 0.2111 - val_masked_accuracy: 0.8210 - 10s/epoch - 182ms/step
# Epoch 12/50
# 56/56 - 10s - loss: 0.1553 - masked_accuracy: 0.8473 - val_loss: 0.2112 - val_masked_accuracy: 0.8006 - 10s/epoch - 176ms/step
# Epoch 13/50
# 56/56 - 11s - loss: 0.1613 - masked_accuracy: 0.8414 - val_loss: 0.2115 - val_masked_accuracy: 0.8237 - 11s/epoch - 193ms/step
# Epoch 14/50
# 56/56 - 10s - loss: 0.1512 - masked_accuracy: 0.8491 - val_loss: 0.2057 - val_masked_accuracy: 0.8204 - 10s/epoch - 179ms/step
# Epoch 15/50
# 56/56 - 10s - loss: 0.1465 - masked_accuracy: 0.8530 - val_loss: 0.2109 - val_masked_accuracy: 0.8121 - 10s/epoch - 176ms/step
# Epoch 16/50
# 56/56 - 10s - loss: 0.1465 - masked_accuracy: 0.8540 - val_loss: 0.2087 - val_masked_accuracy: 0.8232 - 10s/epoch - 178ms/step
# Epoch 17/50
# 56/56 - 11s - loss: 0.1418 - masked_accuracy: 0.8596 - val_loss: 0.2233 - val_masked_accuracy: 0.8262 - 11s/epoch - 193ms/step
# Epoch 18/50
# 56/56 - 10s - loss: 0.1395 - masked_accuracy: 0.8604 - val_loss: 0.2111 - val_masked_accuracy: 0.8232 - 10s/epoch - 178ms/step
# Epoch 19/50
# 56/56 - 10s - loss: 0.1370 - masked_accuracy: 0.8642 - val_loss: 0.2061 - val_masked_accuracy: 0.8193 - 10s/epoch - 177ms/step
# Epoch 20/50
# 56/56 - 10s - loss: 0.1343 - masked_accuracy: 0.8653 - val_loss: 0.2177 - val_masked_accuracy: 0.8177 - 10s/epoch - 178ms/step
# Epoch 21/50
# 56/56 - 10s - loss: 0.1316 - masked_accuracy: 0.8673 - val_loss: 0.2144 - val_masked_accuracy: 0.8204 - 10s/epoch - 178ms/step
# Epoch 22/50
# 56/56 - 10s - loss: 0.1364 - masked_accuracy: 0.8657 - val_loss: 0.2171 - val_masked_accuracy: 0.8135 - 10s/epoch - 177ms/step
# Epoch 23/50
# 56/56 - 10s - loss: 0.1339 - masked_accuracy: 0.8686 - val_loss: 0.2295 - val_masked_accuracy: 0.8213 - 10s/epoch - 175ms/step
# Epoch 24/50
# 56/56 - 11s - loss: 0.1325 - masked_accuracy: 0.8689 - val_loss: 0.2279 - val_masked_accuracy: 0.8267 - 11s/epoch - 192ms/step
# Epoch 25/50
# 56/56 - 10s - loss: 0.1300 - masked_accuracy: 0.8732 - val_loss: 0.2122 - val_masked_accuracy: 0.8213 - 10s/epoch - 177ms/step
# Epoch 26/50
# 56/56 - 10s - loss: 0.1257 - masked_accuracy: 0.8740 - val_loss: 0.2405 - val_masked_accuracy: 0.8175 - 10s/epoch - 176ms/step
# Epoch 27/50
# 56/56 - 10s - loss: 0.1242 - masked_accuracy: 0.8762 - val_loss: 0.2327 - val_masked_accuracy: 0.8192 - 10s/epoch - 177ms/step
# Epoch 28/50
# 56/56 - 11s - loss: 0.1262 - masked_accuracy: 0.8743 - val_loss: 0.2217 - val_masked_accuracy: 0.8270 - 11s/epoch - 190ms/step
# Epoch 29/50
# 56/56 - 10s - loss: 0.1241 - masked_accuracy: 0.8753 - val_loss: 0.2142 - val_masked_accuracy: 0.8222 - 10s/epoch - 176ms/step
# Epoch 30/50
# 56/56 - 10s - loss: 0.1218 - masked_accuracy: 0.8780 - val_loss: 0.2307 - val_masked_accuracy: 0.8168 - 10s/epoch - 177ms/step
# Epoch 31/50
# 56/56 - 10s - loss: 0.1273 - masked_accuracy: 0.8748 - val_loss: 0.2200 - val_masked_accuracy: 0.8123 - 10s/epoch - 176ms/step
# Epoch 32/50
# 56/56 - 10s - loss: 0.1282 - masked_accuracy: 0.8758 - val_loss: 0.2176 - val_masked_accuracy: 0.8219 - 10s/epoch - 175ms/step
# Epoch 33/50
# 56/56 - 10s - loss: 0.1249 - masked_accuracy: 0.8817 - val_loss: 0.2361 - val_masked_accuracy: 0.8181 - 10s/epoch - 176ms/step
# Epoch 34/50
# 56/56 - 10s - loss: 0.1238 - masked_accuracy: 0.8815 - val_loss: 0.2271 - val_masked_accuracy: 0.8228 - 10s/epoch - 176ms/step
# Epoch 35/50
# 56/56 - 10s - loss: 0.1254 - masked_accuracy: 0.8785 - val_loss: 0.2239 - val_masked_accuracy: 0.8218 - 10s/epoch - 181ms/step
# Epoch 36/50
# 56/56 - 10s - loss: 0.1184 - masked_accuracy: 0.8826 - val_loss: 0.2300 - val_masked_accuracy: 0.8236 - 10s/epoch - 176ms/step
# Epoch 37/50
# 56/56 - 10s - loss: 0.1204 - masked_accuracy: 0.8818 - val_loss: 0.2298 - val_masked_accuracy: 0.8220 - 10s/epoch - 176ms/step
# Epoch 38/50
# 56/56 - 10s - loss: 0.1201 - masked_accuracy: 0.8837 - val_loss: 0.2350 - val_masked_accuracy: 0.8191 - 10s/epoch - 177ms/step
# Epoch 39/50
# 56/56 - 10s - loss: 0.1204 - masked_accuracy: 0.8815 - val_loss: 0.2272 - val_masked_accuracy: 0.8186 - 10s/epoch - 175ms/step
# Epoch 40/50
# 56/56 - 10s - loss: 0.1358 - masked_accuracy: 0.8716 - val_loss: 0.2392 - val_masked_accuracy: 0.8029 - 10s/epoch - 176ms/step
# Epoch 41/50
# 56/56 - 10s - loss: 0.1253 - masked_accuracy: 0.8822 - val_loss: 0.2413 - val_masked_accuracy: 0.8237 - 10s/epoch - 177ms/step
# Epoch 42/50
# 56/56 - 10s - loss: 0.1193 - masked_accuracy: 0.8850 - val_loss: 0.2860 - val_masked_accuracy: 0.8119 - 10s/epoch - 176ms/step
# Epoch 43/50
# 56/56 - 10s - loss: 0.1226 - masked_accuracy: 0.8849 - val_loss: 0.2314 - val_masked_accuracy: 0.8243 - 10s/epoch - 177ms/step
# Epoch 44/50
# 56/56 - 10s - loss: 0.1108 - masked_accuracy: 0.8905 - val_loss: 0.2515 - val_masked_accuracy: 0.8229 - 10s/epoch - 177ms/step
# Epoch 45/50
# 56/56 - 10s - loss: 0.1119 - masked_accuracy: 0.8904 - val_loss: 0.2278 - val_masked_accuracy: 0.8206 - 10s/epoch - 176ms/step
# Epoch 46/50
# 56/56 - 11s - loss: 0.1122 - masked_accuracy: 0.8903 - val_loss: 0.2458 - val_masked_accuracy: 0.8277 - 11s/epoch - 193ms/step
# Epoch 47/50
# 56/56 - 10s - loss: 0.1164 - masked_accuracy: 0.8909 - val_loss: 0.2398 - val_masked_accuracy: 0.8248 - 10s/epoch - 177ms/step
# Epoch 48/50
# 56/56 - 10s - loss: 0.1099 - masked_accuracy: 0.8950 - val_loss: 0.2332 - val_masked_accuracy: 0.8179 - 10s/epoch - 182ms/step
# Epoch 49/50
# 56/56 - 10s - loss: 0.1096 - masked_accuracy: 0.8983 - val_loss: 0.2354 - val_masked_accuracy: 0.8259 - 10s/epoch - 177ms/step
# Epoch 50/50
# 56/56 - 10s - loss: 0.1151 - masked_accuracy: 0.8967 - val_loss: 0.2356 - val_masked_accuracy: 0.8215 - 10s/epoch - 176ms/step
